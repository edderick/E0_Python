# %%
import Component
reload(Component)

from bitstring import *

addr = Bits('0b1') * 48
kcp = Bits('0b11111111') * 16
clk = Bits('0b11111111') * 3 + Bits('0b11')

def b(bs, num):
    return bs[num*8: (num+1)*8]

initial1 = b(addr,2)+b(clk,1)+b(kcp, 12)+b(kcp,8)+b(kcp,4)+b(kcp,0)+Bits(uint = int(clk[24]), length =1)
initial1 = BitArray(initial1)
initial1.reverse()


CLU = BitArray(clk[0:4])
CLU.reverse()

CLL = BitArray(clk[4:8])
CLL.reverse()
initial2 = b(addr,3)+b(addr,0)+b(kcp,13)+b(kcp,9)+b(kcp,5)+b(kcp,1)+CLL+Bits('0b001')
initial2 = BitArray(initial2)
initial2.reverse()

initial3 = b(addr,4)+b(clk,2)+b(kcp,14)+b(kcp,10)+b(kcp,6)+b(kcp,2)+Bits(uint = int(clk[25]), length=1)
initial3 = BitArray(initial3)
initial3.reverse()

initial4 = b(addr,5)+b(addr,1)+b(addr,15)+b(kcp,15)+b(kcp,11)+b(kcp,7)+b(kcp,3)+CLU+Bits('0b111')
initial4 = BitArray(initial4)
initial4.reverse()



mask1 = Bits(uint = 139297, length = 25)        #Bits('0b0000000100010000000100001')                L1
mask2 = Bits(uint = 557185, length = 31)        #Bits('0b0000000000010001000000010000001')          L2
mask3 = Bits(uint = 536871457, length = 33)     #Bits('0b000100000000000000000001000100001')        L3
mask4 = Bits(uint = 34359740425, length = 39)   #Bits('0b000100000000000000000000000100000001001')  L4

output1 = 23
output2 = 23
output3 = 31
output4 = 31

DSource1 = Component.DynamicSource(initial1,Bits('0b0'))
DSource2 = Component.DynamicSource(initial2,Bits('0b0'))
DSource3 = Component.DynamicSource(initial3,Bits('0b0'))
DSource4 = Component.DynamicSource(initial4,Bits('0b0'))

LFSR1 = Component.LFSR(DSource1, mask1, output1)
LFSR2 = Component.LFSR(DSource2, mask2, output2)
LFSR3 = Component.LFSR(DSource3, mask3, output3)
LFSR4 = Component.LFSR(DSource4, mask4, output4)

LFSRAdder = Component.Adder(3, LFSR1, LFSR2, LFSR3, LFSR4)

blendAdder = Component.Adder(3, LFSRAdder)

divider = Component.Divider(2, blendAdder)

blendXOR = Component.ExclusiveOR(divider)

topDelay =Component.Delay(Bits('0b00'),blendXOR)

T1 = Component.Bijection(Component.Bijection.T1_values, topDelay)

bottomDelay = Component.Delay(Bits('0b00'),topDelay)

T2 = Component.Bijection(Component.Bijection.T2_values, bottomDelay)

blendSlice = Component.Slice(1,2, topDelay)

bigXOR = Component.ExclusiveOR(LFSR1, LFSR2, LFSR3, LFSR4, blendSlice)

blendAdder.addInput(topDelay)
blendXOR.addInput(T1)
blendXOR.addInput(T2)


output = Component.Output(bigXOR)

for i in range(240):
    if(i <=40):
        topDelay.outputs[-1] = Bits('0b00')
        bottomDelay.outputs[-1] = Bits('0b00')
    output.step(i)
    
    
for i in range(240):
    print i, LFSR1.outputs[i].bin, LFSR2.outputs[i].bin, LFSR3.outputs[i].bin, LFSR4.outputs[i].bin, "Z", output.outputs[i].bin, "C[t+1]",blendXOR.outputs[i].bin, "c[t]",topDelay.outputs[i].bin, "blendslice[t]", blendSlice.outputs[i].bin
    #print i, "Z", output.outputs[i].bin, "LSFRs", LFSR1.outputs[i].bin, LFSR2.outputs[i].bin, LFSR3.outputs[i].bin, LFSR4.outputs[i].bin, "C[t+1]", blendXOR.outputs[i].bin, "C[t]", topDelay.outputs[i].bin 
    #print i, "LSFR1", LFSR1.register,"LFSR2", LFSR2.register.bin, "LFSR3", LFSR3.register, "LFSR4", foo
    #print i, foo
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-2c0d19f2ae14> in <module>()
#      90
#      91 for i in range(240):
# ---> 92     print i, LFSR1.outputs[i].bin, LFSR2.outputs[i].bin, LFSR3.outputs[i].bin, LFSR4.outputs[i].bin, "Z", output.outputs[i].bin, "C[t+1]",blendXOR.outputs[i].bin, "c[t]",topDelay.outputs[i].bin, "blendslice[t]", blendSlice.outputs[i].bin
#      93     #print i, "Z", output.outputs[i].bin, "LSFRs", LFSR1.outputs[i].bin, LFSR2.outputs[i].bin, LFSR3.outputs[i].bin, LFSR4.outputs[i].bin, "C[t+1]", blendXOR.outputs[i].bin, "C[t]", topDelay.outputs[i].bin
#      94     #print i, "LSFR1", LFSR1.register,"LFSR2", LFSR2.register.bin, "LFSR3", LFSR3.register, "LFSR4", foo
#
# IndexError: list index out of range
#  0 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 1 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 2 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 3 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 4 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 5 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 6 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 7 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 8 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 9 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 10 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 11 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 12 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 13 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 14 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 15 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 16 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 17 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 18 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 19 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 20 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 21 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 22 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 23 0 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 24 1 1 0 0 Z 0 C[t+1] 01 c[t] 00 blendslice[t] 0
# 25 1 0 0 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 1
# 26 1 0 0 0 Z 1 C[t+1] 00 c[t] 00 blendslice[t] 0
# 27 1 1 0 0 Z 0 C[t+1] 01 c[t] 00 blendslice[t] 0
# 28 1 1 0 0 Z 1 C[t+1] 01 c[t] 00 blendslice[t] 1
# 29 1 1 0 0 Z 1 C[t+1] 01 c[t] 00 blendslice[t] 1
# 30 1 1 0 0 Z 1 C[t+1] 01 c[t] 00 blendslice[t] 1
# 31 1 1 0 0 Z 1 C[t+1] 01 c[t] 00 blendslice[t] 1
# 32 1 1 1 1 Z 1 C[t+1] 10 c[t] 00 blendslice[t] 1
# 33 1 1 1 1 Z 0 C[t+1] 10 c[t] 00 blendslice[t] 0
# 34 1 1 1 1 Z 0 C[t+1] 10 c[t] 00 blendslice[t] 0
# 35 1 1 1 1 Z 0 C[t+1] 10 c[t] 00 blendslice[t] 0
# 36 1 1 1 1 Z 0 C[t+1] 10 c[t] 00 blendslice[t] 0
# 37 1 1 1 1 Z 0 C[t+1] 10 c[t] 00 blendslice[t] 0
# 38 1 1 1 1 Z 0 C[t+1] 10 c[t] 00 blendslice[t] 0
# 39 1 1 1 1 Z 0 C[t+1] 10 c[t] 00 blendslice[t] 0
# 40 1 1 1 1 Z 0 C[t+1] 01 c[t] 10 blendslice[t] 0
# 41 1 1 1 1 Z 1 C[t+1] 10 c[t] 01 blendslice[t] 1
# 42 1 1 1 1 Z 0 C[t+1] 10 c[t] 10 blendslice[t] 0
# 43 1 1 1 1 Z 0 C[t+1] 00 c[t] 10 blendslice[t] 0
# 44 1 1 1 1 Z 0 C[t+1] 11 c[t] 00 blendslice[t] 0
# 45 1 1 1 1 Z 1 C[t+1] 00 c[t] 11 blendslice[t] 1
# 46 1 1 1 1 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 47 1 1 1 1 Z 0 C[t+1] 10 c[t] 00 blendslice[t] 0
# 48 1 1 1 1 Z 0 C[t+1] 01 c[t] 10 blendslice[t] 0
# 49 1 1 1 1 Z 1 C[t+1] 10 c[t] 01 blendslice[t] 1
# 50 1 1 1 1 Z 0 C[t+1] 10 c[t] 10 blendslice[t] 0
# 51 1 1 1 1 Z 0 C[t+1] 00 c[t] 10 blendslice[t] 0
# 52 1 1 1 1 Z 0 C[t+1] 11 c[t] 00 blendslice[t] 0
# 53 1 1 1 1 Z 1 C[t+1] 00 c[t] 11 blendslice[t] 1
# 54 1 1 1 1 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 55 1 1 1 1 Z 0 C[t+1] 10 c[t] 00 blendslice[t] 0
# 56 1 0 1 1 Z 1 C[t+1] 00 c[t] 10 blendslice[t] 0
# 57 1 0 1 1 Z 1 C[t+1] 00 c[t] 00 blendslice[t] 0
# 58 1 1 1 1 Z 0 C[t+1] 10 c[t] 00 blendslice[t] 0
# 59 1 1 1 1 Z 0 C[t+1] 01 c[t] 10 blendslice[t] 0
# 60 1 1 1 1 Z 1 C[t+1] 10 c[t] 01 blendslice[t] 1
# 61 1 1 1 1 Z 0 C[t+1] 10 c[t] 10 blendslice[t] 0
# 62 1 1 1 1 Z 0 C[t+1] 00 c[t] 10 blendslice[t] 0
# 63 1 1 1 1 Z 0 C[t+1] 11 c[t] 00 blendslice[t] 0
# 64 1 1 1 1 Z 1 C[t+1] 00 c[t] 11 blendslice[t] 1
# 65 1 1 1 1 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 66 1 1 1 1 Z 0 C[t+1] 10 c[t] 00 blendslice[t] 0
# 67 1 1 1 1 Z 0 C[t+1] 01 c[t] 10 blendslice[t] 0
# 68 1 0 1 1 Z 0 C[t+1] 10 c[t] 01 blendslice[t] 1
# 69 1 0 1 1 Z 1 C[t+1] 11 c[t] 10 blendslice[t] 0
# 70 1 1 1 1 Z 1 C[t+1] 01 c[t] 11 blendslice[t] 1
# 71 1 1 1 1 Z 1 C[t+1] 01 c[t] 01 blendslice[t] 1
# 72 1 0 1 1 Z 0 C[t+1] 00 c[t] 01 blendslice[t] 1
# 73 0 0 1 1 Z 0 C[t+1] 10 c[t] 00 blendslice[t] 0
# 74 0 1 1 1 Z 1 C[t+1] 00 c[t] 10 blendslice[t] 0
# 75 0 1 1 1 Z 1 C[t+1] 00 c[t] 00 blendslice[t] 0
# 76 0 1 1 1 Z 1 C[t+1] 01 c[t] 00 blendslice[t] 0
# 77 0 1 1 1 Z 0 C[t+1] 11 c[t] 01 blendslice[t] 1
# 78 0 1 1 1 Z 0 C[t+1] 11 c[t] 11 blendslice[t] 1
# 79 0 0 1 1 Z 1 C[t+1] 11 c[t] 11 blendslice[t] 1
# 80 0 0 1 1 Z 1 C[t+1] 11 c[t] 11 blendslice[t] 1
# 81 1 0 0 1 Z 1 C[t+1] 11 c[t] 11 blendslice[t] 1
# 82 1 0 0 1 Z 1 C[t+1] 11 c[t] 11 blendslice[t] 1
# 83 1 0 0 1 Z 1 C[t+1] 11 c[t] 11 blendslice[t] 1
# 84 1 0 0 1 Z 1 C[t+1] 11 c[t] 11 blendslice[t] 1
# 85 0 0 1 1 Z 1 C[t+1] 11 c[t] 11 blendslice[t] 1
# 86 0 0 1 1 Z 1 C[t+1] 11 c[t] 11 blendslice[t] 1
# 87 0 1 1 0 Z 1 C[t+1] 11 c[t] 11 blendslice[t] 1
# 88 0 0 1 0 Z 0 C[t+1] 11 c[t] 11 blendslice[t] 1
# 89 1 1 0 0 Z 1 C[t+1] 11 c[t] 11 blendslice[t] 1
# 90 1 0 0 0 Z 0 C[t+1] 11 c[t] 11 blendslice[t] 1
# 91 1 1 0 1 Z 0 C[t+1] 10 c[t] 11 blendslice[t] 1
# 92 1 0 0 1 Z 0 C[t+1] 10 c[t] 10 blendslice[t] 0
# 93 0 0 1 1 Z 0 C[t+1] 01 c[t] 10 blendslice[t] 0
# 94 0 1 1 1 Z 0 C[t+1] 10 c[t] 01 blendslice[t] 1
# 95 0 0 1 0 Z 1 C[t+1] 00 c[t] 10 blendslice[t] 0
# 96 0 1 1 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 97 0 1 0 0 Z 1 C[t+1] 00 c[t] 00 blendslice[t] 0
# 98 1 0 0 0 Z 1 C[t+1] 00 c[t] 00 blendslice[t] 0
# 99 1 0 0 1 Z 0 C[t+1] 01 c[t] 00 blendslice[t] 0
# 100 1 1 0 1 Z 0 C[t+1] 11 c[t] 01 blendslice[t] 1
# 101 0 1 1 1 Z 0 C[t+1] 11 c[t] 11 blendslice[t] 1
# 102 0 0 1 1 Z 1 C[t+1] 11 c[t] 11 blendslice[t] 1
# 103 0 0 1 0 Z 0 C[t+1] 11 c[t] 11 blendslice[t] 1
# 104 0 0 1 0 Z 0 C[t+1] 11 c[t] 11 blendslice[t] 1
# 105 0 0 1 0 Z 0 C[t+1] 11 c[t] 11 blendslice[t] 1
# 106 0 0 1 0 Z 0 C[t+1] 11 c[t] 11 blendslice[t] 1
# 107 0 0 1 1 Z 1 C[t+1] 11 c[t] 11 blendslice[t] 1
# 108 0 0 1 1 Z 1 C[t+1] 11 c[t] 11 blendslice[t] 1
# 109 0 0 1 1 Z 1 C[t+1] 11 c[t] 11 blendslice[t] 1
# 110 0 1 1 1 Z 0 C[t+1] 10 c[t] 11 blendslice[t] 1
# 111 0 1 1 0 Z 0 C[t+1] 10 c[t] 10 blendslice[t] 0
# 112 0 0 1 0 Z 1 C[t+1] 10 c[t] 10 blendslice[t] 0
# 113 0 1 1 0 Z 0 C[t+1] 01 c[t] 10 blendslice[t] 0
# 114 1 0 0 0 Z 0 C[t+1] 01 c[t] 01 blendslice[t] 1
# 115 1 1 0 0 Z 1 C[t+1] 11 c[t] 01 blendslice[t] 1
# 116 1 1 0 0 Z 1 C[t+1] 10 c[t] 11 blendslice[t] 1
# 117 1 1 0 0 Z 0 C[t+1] 10 c[t] 10 blendslice[t] 0
# 118 1 0 0 0 Z 1 C[t+1] 10 c[t] 10 blendslice[t] 0
# 119 1 0 0 1 Z 0 C[t+1] 01 c[t] 10 blendslice[t] 0
# 120 1 0 0 1 Z 1 C[t+1] 01 c[t] 01 blendslice[t] 1
# 121 0 1 0 1 Z 1 C[t+1] 11 c[t] 01 blendslice[t] 1
# 122 1 0 1 1 Z 0 C[t+1] 11 c[t] 11 blendslice[t] 1
# 123 0 1 1 0 Z 1 C[t+1] 11 c[t] 11 blendslice[t] 1
# 124 0 1 1 0 Z 1 C[t+1] 11 c[t] 11 blendslice[t] 1
# 125 0 1 1 0 Z 1 C[t+1] 11 c[t] 11 blendslice[t] 1
# 126 0 1 1 1 Z 0 C[t+1] 10 c[t] 11 blendslice[t] 1
# 127 0 1 1 0 Z 0 C[t+1] 10 c[t] 10 blendslice[t] 0
# 128 0 0 1 0 Z 1 C[t+1] 10 c[t] 10 blendslice[t] 0
# 129 1 0 0 0 Z 1 C[t+1] 10 c[t] 10 blendslice[t] 0
# 130 0 0 1 0 Z 1 C[t+1] 10 c[t] 10 blendslice[t] 0
# 131 1 0 1 1 Z 1 C[t+1] 01 c[t] 10 blendslice[t] 0
# 132 1 0 1 1 Z 0 C[t+1] 10 c[t] 01 blendslice[t] 1
# 133 0 0 0 1 Z 1 C[t+1] 00 c[t] 10 blendslice[t] 0
# 134 0 1 0 0 Z 1 C[t+1] 01 c[t] 00 blendslice[t] 0
# 135 1 0 0 1 Z 1 C[t+1] 00 c[t] 01 blendslice[t] 1
# 136 1 1 0 1 Z 1 C[t+1] 10 c[t] 00 blendslice[t] 0
# 137 0 1 1 1 Z 1 C[t+1] 00 c[t] 10 blendslice[t] 0
# 138 1 1 0 1 Z 1 C[t+1] 00 c[t] 00 blendslice[t] 0
# 139 1 1 0 0 Z 0 C[t+1] 01 c[t] 00 blendslice[t] 0
# 140 1 0 0 0 Z 0 C[t+1] 00 c[t] 01 blendslice[t] 1
# 141 0 1 1 0 Z 0 C[t+1] 10 c[t] 00 blendslice[t] 0
# 142 0 0 1 1 Z 0 C[t+1] 00 c[t] 10 blendslice[t] 0
# 143 1 1 1 1 Z 0 C[t+1] 11 c[t] 00 blendslice[t] 0
# 144 1 1 1 1 Z 1 C[t+1] 00 c[t] 11 blendslice[t] 1
# 145 1 1 0 1 Z 1 C[t+1] 11 c[t] 00 blendslice[t] 0
# 146 1 0 1 1 Z 0 C[t+1] 00 c[t] 11 blendslice[t] 1
# 147 1 0 0 1 Z 0 C[t+1] 11 c[t] 00 blendslice[t] 0
# 148 0 1 0 1 Z 1 C[t+1] 01 c[t] 11 blendslice[t] 1
# 149 1 0 1 1 Z 0 C[t+1] 01 c[t] 01 blendslice[t] 1
# 150 1 1 1 0 Z 0 C[t+1] 00 c[t] 01 blendslice[t] 1
# 151 1 0 0 1 Z 0 C[t+1] 10 c[t] 00 blendslice[t] 0
# 152 1 0 0 1 Z 0 C[t+1] 00 c[t] 10 blendslice[t] 0
# 153 1 0 0 1 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 154 0 0 1 1 Z 0 C[t+1] 01 c[t] 00 blendslice[t] 0
# 155 1 1 1 0 Z 0 C[t+1] 11 c[t] 01 blendslice[t] 1
# 156 1 0 1 0 Z 1 C[t+1] 10 c[t] 11 blendslice[t] 1
# 157 1 1 1 0 Z 1 C[t+1] 10 c[t] 10 blendslice[t] 0
# 158 1 0 1 1 Z 1 C[t+1] 01 c[t] 10 blendslice[t] 0
# 159 1 1 1 0 Z 0 C[t+1] 10 c[t] 01 blendslice[t] 1
# 160 1 1 1 0 Z 1 C[t+1] 11 c[t] 10 blendslice[t] 0
# 161 1 0 1 0 Z 1 C[t+1] 00 c[t] 11 blendslice[t] 1
# 162 1 0 1 0 Z 0 C[t+1] 11 c[t] 00 blendslice[t] 0
# 163 0 1 0 1 Z 1 C[t+1] 01 c[t] 11 blendslice[t] 1
# 164 0 1 0 1 Z 1 C[t+1] 10 c[t] 01 blendslice[t] 1
# 165 0 0 0 0 Z 0 C[t+1] 00 c[t] 10 blendslice[t] 0
# 166 0 1 0 1 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 167 1 1 1 0 Z 1 C[t+1] 01 c[t] 00 blendslice[t] 0
# 168 1 0 1 0 Z 1 C[t+1] 00 c[t] 01 blendslice[t] 1
# 169 0 1 1 1 Z 1 C[t+1] 10 c[t] 00 blendslice[t] 0
# 170 0 1 1 1 Z 1 C[t+1] 00 c[t] 10 blendslice[t] 0
# 171 1 0 0 1 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 172 1 1 0 1 Z 1 C[t+1] 01 c[t] 00 blendslice[t] 0
# 173 0 1 0 1 Z 1 C[t+1] 00 c[t] 01 blendslice[t] 1
# 174 0 0 0 0 Z 0 C[t+1] 11 c[t] 00 blendslice[t] 0
# 175 1 1 1 1 Z 1 C[t+1] 00 c[t] 11 blendslice[t] 1
# 176 1 1 1 1 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 177 0 0 0 1 Z 1 C[t+1] 00 c[t] 00 blendslice[t] 0
# 178 0 1 0 1 Z 0 C[t+1] 01 c[t] 00 blendslice[t] 0
# 179 1 0 1 1 Z 0 C[t+1] 11 c[t] 01 blendslice[t] 1
# 180 0 1 0 1 Z 1 C[t+1] 10 c[t] 11 blendslice[t] 1
# 181 0 1 1 0 Z 0 C[t+1] 10 c[t] 10 blendslice[t] 0
# 182 0 0 1 0 Z 1 C[t+1] 10 c[t] 10 blendslice[t] 0
# 183 1 0 0 1 Z 0 C[t+1] 01 c[t] 10 blendslice[t] 0
# 184 1 0 0 1 Z 1 C[t+1] 01 c[t] 01 blendslice[t] 1
# 185 1 0 1 0 Z 1 C[t+1] 11 c[t] 01 blendslice[t] 1
# 186 1 0 1 0 Z 1 C[t+1] 10 c[t] 11 blendslice[t] 1
# 187 0 0 0 1 Z 1 C[t+1] 01 c[t] 10 blendslice[t] 0
# 188 0 0 0 1 Z 0 C[t+1] 01 c[t] 01 blendslice[t] 1
# 189 0 1 1 1 Z 0 C[t+1] 00 c[t] 01 blendslice[t] 1
# 190 0 1 1 0 Z 0 C[t+1] 10 c[t] 00 blendslice[t] 0
# 191 1 1 0 1 Z 1 C[t+1] 00 c[t] 10 blendslice[t] 0
# 192 1 0 0 1 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 193 0 0 1 0 Z 1 C[t+1] 00 c[t] 00 blendslice[t] 0
# 194 1 1 1 0 Z 1 C[t+1] 01 c[t] 00 blendslice[t] 0
# 195 0 1 0 1 Z 1 C[t+1] 00 c[t] 01 blendslice[t] 1
# 196 1 0 1 1 Z 1 C[t+1] 10 c[t] 00 blendslice[t] 0
# 197 0 1 0 0 Z 1 C[t+1] 11 c[t] 10 blendslice[t] 0
# 198 1 1 0 1 Z 0 C[t+1] 01 c[t] 11 blendslice[t] 1
# 199 0 1 1 1 Z 0 C[t+1] 01 c[t] 01 blendslice[t] 1
# 200 0 0 1 1 Z 1 C[t+1] 11 c[t] 01 blendslice[t] 1
# 201 1 0 1 1 Z 0 C[t+1] 11 c[t] 11 blendslice[t] 1
# 202 1 0 1 1 Z 0 C[t+1] 10 c[t] 11 blendslice[t] 1
# 203 0 0 0 1 Z 1 C[t+1] 01 c[t] 10 blendslice[t] 0
# 204 0 0 0 0 Z 1 C[t+1] 00 c[t] 01 blendslice[t] 1
# 205 1 0 0 0 Z 1 C[t+1] 11 c[t] 00 blendslice[t] 0
# 206 1 1 0 1 Z 0 C[t+1] 00 c[t] 11 blendslice[t] 1
# 207 0 1 1 1 Z 1 C[t+1] 11 c[t] 00 blendslice[t] 0
# 208 0 0 1 1 Z 1 C[t+1] 01 c[t] 11 blendslice[t] 1
# 209 0 0 1 0 Z 0 C[t+1] 10 c[t] 01 blendslice[t] 1
# 210 1 0 0 0 Z 1 C[t+1] 00 c[t] 10 blendslice[t] 0
# 211 0 1 1 0 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 212 1 1 0 0 Z 0 C[t+1] 01 c[t] 00 blendslice[t] 0
# 213 0 0 1 1 Z 1 C[t+1] 00 c[t] 01 blendslice[t] 1
# 214 1 0 1 0 Z 0 C[t+1] 10 c[t] 00 blendslice[t] 0
# 215 0 0 0 1 Z 1 C[t+1] 11 c[t] 10 blendslice[t] 0
# 216 0 0 0 1 Z 0 C[t+1] 00 c[t] 11 blendslice[t] 1
# 217 0 0 1 1 Z 0 C[t+1] 11 c[t] 00 blendslice[t] 0
# 218 1 0 0 1 Z 1 C[t+1] 01 c[t] 11 blendslice[t] 1
# 219 1 0 1 0 Z 1 C[t+1] 10 c[t] 01 blendslice[t] 1
# 220 1 1 1 1 Z 0 C[t+1] 10 c[t] 10 blendslice[t] 0
# 221 0 0 0 1 Z 1 C[t+1] 10 c[t] 10 blendslice[t] 0
# 222 1 1 0 0 Z 0 C[t+1] 01 c[t] 10 blendslice[t] 0
# 223 1 1 1 1 Z 1 C[t+1] 10 c[t] 01 blendslice[t] 1
# 224 1 1 1 1 Z 0 C[t+1] 10 c[t] 10 blendslice[t] 0
# 225 1 1 1 0 Z 1 C[t+1] 01 c[t] 10 blendslice[t] 0
# 226 0 1 0 0 Z 0 C[t+1] 01 c[t] 01 blendslice[t] 1
# 227 0 1 1 0 Z 1 C[t+1] 11 c[t] 01 blendslice[t] 1
# 228 1 0 0 0 Z 0 C[t+1] 10 c[t] 11 blendslice[t] 1
# 229 0 1 1 1 Z 1 C[t+1] 10 c[t] 10 blendslice[t] 0
# 230 0 0 1 0 Z 1 C[t+1] 10 c[t] 10 blendslice[t] 0
# 231 1 1 0 1 Z 1 C[t+1] 01 c[t] 10 blendslice[t] 0
# 232 1 1 0 1 Z 0 C[t+1] 10 c[t] 01 blendslice[t] 1
# 233 1 0 1 1 Z 1 C[t+1] 11 c[t] 10 blendslice[t] 0
# 234 0 1 0 1 Z 1 C[t+1] 00 c[t] 11 blendslice[t] 1
# 235 0 0 1 0 Z 1 C[t+1] 10 c[t] 00 blendslice[t] 0
# 236 0 1 1 1 Z 1 C[t+1] 00 c[t] 10 blendslice[t] 0
# 237 0 0 1 1 Z 0 C[t+1] 00 c[t] 00 blendslice[t] 0
# 238 1 1 1 1 Z 0 C[t+1] 10 c[t] 00 blendslice[t] 0
# 239 1 0 0 0 Z 1 C[t+1]
